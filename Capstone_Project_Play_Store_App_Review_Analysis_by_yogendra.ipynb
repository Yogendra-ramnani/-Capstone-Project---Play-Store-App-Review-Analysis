# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogendra-ramnani/-Capstone-Project---Play-Store-App-Review-Analysis/blob/main/Capstone_Project_Play_Store_App_Review_Analysis_by_yogendra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# # **Importing Libraries**

# %%
# Importing libraries (Numpy, Pandas, seaborn and matplotlib.pyplot etc) to complete the project

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # **Mounting Google drive and CSV file and it's path**

# %% [markdown]
# * They provided us two different CSV files (Data frames).
#
#
# * First data frame is play store data frame which contains all the details of the app, and second data frame is user review dataset which contains the user reviews of the respective app.
#
# * We have to explore the data present in the data frame for each row and column which help us analysing and through that we get required output.

# %%
# Mounting Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing play store data.csv as ps_df

ps_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CAPSTONE PROJECT/EDA PROJECT/Copy of Play Store Data.csv')

# %%
# Importing user review.csv as ur_df

ur_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CAPSTONE PROJECT/EDA PROJECT/Copy of User Reviews.csv')

# %% [markdown]
# # **Exploring Play store dataset**

# %%
# Inspecting play store dataset Rows, Columns, with the help of [df.head(), df.tail(), df.shape, df.columns, df.info(), df.describe()]
## ps_df.head() [It's display the top five rows of play store data frame with columns name]

ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# ps_df.tail() [It's display the bottom five rows of play store data frame with columns name]

ps_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# ps_df.shape [It's display total the number of rows and columns present in play store data frame]

ps_df.shape
# Out:
# (10841, 13)

# %%
# ps_df.columns [It's display all columns name list present in play store data frame]

ps_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# ps_df.info() [It's display columns name and there non- null count with respective data type (Dtype)]

ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# ps_df.describe() [It's display the statistical summary of the numeric column present in play store data frame]

ps_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# # **Now Exploring User review dataset**

# %%
# Inspecting user review dataset Rows, Columns, with the help of[df.head(), df.tail(), df.shape, df.columns, df.info(), df.describe()]
## Ur_df.head() [It's display the top five rows of user review data frame with columns name]

ur_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# ur_df.tail() [It's display the bottom five rows of user review dataset with columns name]

ur_df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# ur_df.shape [It's display total number of rows and columns present in user review data frame]

ur_df.shape
# Out:
# (64295, 5)

# %%
# ur_df.columns [It's display all columns name list present in user view data frame]

ur_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# ur_df.info() [It's display columns name and there non- null count with respective data type present in user review data frame]

ur_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# ur_df.describe() [It's display the statistical summary of the numeric columns present in user review dataset ]

ur_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# #**Cleaning junk values from data frame**
#
# * Cleaning and handling the junk values (NAN values and error values) after find NaN values and error values count we are going to replace those value with respective columns available data or we are going to drop respective rows which containing those NaN values.
#
# **NOTE** - Nan values are those values which does not contain any entry.
#
# **Play store dataset cleaning**

# %%
# Let find the Nan values count each column wise and to the respective operation on those values 
## ps_df.isna().sum() [It's display the sum of the null values for each columns present in data frame]

ps_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# **1 - "Type" Column**

# %%
# In [ps_df.isna().sum()] we find that column name "Type" have 1 NaN value so we are going either replace the value or drop the row
## Row which are containing NaN values in "Type" column

type_clm_nanvalue_df = ps_df[ps_df['Type'].isnull()]
type_clm_nanvalue_df
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
# How many types of App present in dataframe

types_of_app_df = ps_df.Type.value_counts()
types_of_app_df
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# 1. As per our observation we know that the "Type" column contains only two unique values 'Free' and 'Paid.
# 2. Also we get that Paid App have repective values in "Price" column but in this operation we found price showing '0' value it's mean the App type is free.
# 3. So now we can replace this NaN value with Free.

# %%
# Replacing the NaN value in 'Type' column with 'Free' in row I'D = 9148	

rep_nanvalue_df = ps_df.loc[9148,'Type'] = 'Free'

# %% [markdown]
# **2 - "Android Ver" Column**
#
# Now we are going to handle "Android Ver" column becuse it's have lesser number of NaN values.so we can find the reson why Nan values there, should we replace them or remove the respective rows.
#
# "Android Ver" - 3 NaN values

# %%
# Rows which are containing NaN values in 'Android Ver' column

androidver_clm_nanvalue_df = ps_df[ps_df['Android Ver'].isnull()]
androidver_clm_nanvalue_df
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %% [markdown]
# 1. As we know every App has different Android Version, so the NaN values in the"Android Ver" column cannot be replaced by any particular value.
# 2. so we are going to drop all three rows from the data frame.

# %%
# Dropping all three rows from the data frame
## ps_df.drop() [Drop method drop the row or column from data frame] [inplace = True, is perfom the method or function in the main data frame]
### Previous shape data frame = (10841, 13)

drop_3_nanvalue_df = ps_df.drop([4453, 4490, 10472], inplace=True)
drop_3_nanvalue_df

# %%
# Current shape of play store data frame

ps_df.shape
# Out:
# (10838, 13)

# %% [markdown]
# **3 - "Current Ver" Column**
#
# Now we are going to handle Current Ver column becuse it's have 8 number of NaN values.

# %%
# Rows which are containing NaN values in the Current Ver column

currentver_clm_nanvalue_df = ps_df[ps_df['Current Ver'].isnull()]
currentver_clm_nanvalue_df
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %% [markdown]
# * Now we are going to find different values of "Current Ver" after that we check can we replace those values in 8 rows if we can't then we drop all 8 rows from our dataset.

# %%
# Different values which present in 'Current Ver' column
## value_counts() [it's display counts of unique values present in columns]

currentver_value_count_df = ps_df['Current Ver'].value_counts()
currentver_value_count_df
# Out:
# Varies with device    1459
# 1.0                    809
# 1.1                    263
# 1.2                    178
# 2.0                    151
#                       ...
# 5.44.1                   1
# 7.16.8                   1
# 04.08.00                 1
# 2.10.06                  1
# 2.0.148.0                1
# Name: Current Ver, Length: 2831, dtype: int64

# %% [markdown]
# 1. As we know there are only 8 rows which contain NaN values in the `Current Ver` column, and there is no define value with which we can replce those 8 values.
# 2. so we are going to drop those 8 rows.

# %%
# Dropping all 8 rows from the data set 

ps_df = ps_df[ps_df['Current Ver'].notna()]
ps_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Current dataset shape
## Previous shape data set = (10838, 13)
ps_df.shape
# Out:
# (10830, 13)

# %%
# After the few operation lets check what is the out put
## ps_df.isna().sum() [It's display the sum of the null values for each columns present in dataset]
ps_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1470
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %% [markdown]
# **4 - "Rating" Column**
# *  As we can see Rating column contain 1470 NaN values.
# *  it's a large number of data so we can't drop all the rows if we do that than we will loose large amount of data.
# *  Hence we are going to replace NaN values with the mean or median of the Rating column present values.
# * For find mean and median we are going take help of different type of graphs and plots and Those plot help us in further data analysis.

# %%
# Rows which are containing NaN values in the "Rating" column.

ratting_clm_nanvalue_df = ps_df[ps_df['Rating'].isnull()]
ratting_clm_nanvalue_df
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# **a) - Boxplot (Whisker plot)** - From the help of Boxplot we are able to find the median of the "Rating" column present data we plot.

# %%
# Boxplot [It's display minimum,maximum,first quartile,median(2nd quartile) and third quartile]
## For plotting this graph we take the help of matplotlib and seborn library

from numpy.ma.extras import median

plot_figure = plt.figure(figsize =(10,5))
sns.boxplot(data = ps_df['Rating'] ,orient="h", x= ps_df['Rating'])
median = ps_df['Rating'].median()

plt.title ("Boxplot of Rating values")
# Out:
# Text(0.5, 1.0, 'Boxplot of Rating values')

# %% [markdown]
# **b) - Distribution plot (displot)**- It's display univarint set of collected data for the one variable shown against another variable.
# * Which help to replace NaN values either with mean or median

# %%
#Displot [ It's display data distrbution in different values which are the present in the define series]
## For plotting this graph we take the help of matplotlib and seborn library

sns.set(rc={'figure.figsize':(15,8)})
sns.distplot(ps_df['Rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1. From the above Boxplot and Displot graph, we can come to the conclusion that most of the apps in the play store are rated between the range of 3.0 to 5.0 and also mean and median for the 'Rating' column according to present values
# (excluding Nan values).
# * Mean = 4.2
# * Median = 4.3
# 2. We alose note that the displot graph is left skewed and is not catagorical, it is not recomamended to use mean for replacing the NaN value.
# 3. Hence we will impute the NaN values in the Rating column with its median.

# %%
# Cross checking the value of mean in the 'Rating' column

ps_df['Rating'].mean()
# Out:
# 4.191837606837606

# %%
# Cross checking the value of median in the 'Rating' column

ps_df['Rating'].median()
# Out:
# 4.3

# %%
# Replacing the NaN values in the 'Rating' colunm with its median value which is 4.3 with help of impute
## By imputation, we mean to replace the NaN values with a particular value in the entire dataset

impute_median = ps_df['Rating'].median()
ps_df['Rating'] = ps_df['Rating'].fillna(impute_median)

# %% [markdown]
# **Plotting histogram and displot** - After replacing the NaN values with the median we are going to visualise the "Rating" column once again in histrogram and displot for cross check the our output.
#
# **c) - Histrogram**- It's display summarize data and it's a visual interpretation of numeric data.
# * Which help us to verify that after operation values which we change does not impact our main data and the change with in the range between 0.0 to 5.0.

# %%
# Plotting histogram
## For plotting this graph we take the help of matplotlib and seborn library

ps_df ['Rating'].hist()

# %%
#Displot [ It's display data distrbution in different values which are the present in the define series]
## For plotting this graph we take the help of matplotlib and seborn library

sns.set(rc={'figure.figsize':(15,8)})
sns.distplot(ps_df['Rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Output** - After replacing the NaN values we observe that there is no major devation in our main data frame (orignal values).

# %% [markdown]
# # **Changing in columns Data type (Dtype)**
#
# 1. Change and clean the string values present into different columns.
# 2. Converting 'Review','Price', 'Installs' and 'Size' columns into valid numeric columns.

# %%
# ps_df.info() [It's display columns name and there non- null count with respective data type (Dtype)]

ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10830 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10830 non-null  object
#  1   Category        10830 non-null  object
#  2   Rating          10830 non-null  float64
#  3   Reviews         10830 non-null  object
#  4   Size            10830 non-null  object
#  5   Installs        10830 non-null  object
#  6   Type            10830 non-null  object
#  7   Price           10830 non-null  object
#  8   Content Rating  10830 non-null  object
#  9   Genres          10830 non-null  object
#  10  Last Updated    10830 non-null  object
#  11  Current Ver     10830 non-null  object
#  12  Android Ver     10830 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.4+ MB

# %%
# ps_df.iloc[: , :] [It's slicing operation in dataframe which display required rows and columns which index we put in the code]

ps_df.iloc[9558:9573]
# Out:
#                                                    App             Category  \
# 9567                                  Adivina el Emoji                 GAME
# 9568                            Weather by eltiempo.es              WEATHER
# 9569                                  The Game of Life                 GAME
# 9570                        Spanish English Translator  BOOKS_AND_REFERENCE
# 9571                                   The Holy Rosary            LIFESTYLE
# 9572   Western Union US - Send Money Transfers Quickly              FINANCE
# 9573    Maps, GPS Navigation & Directions, Street View  MAPS_AND_NAVIGATION
# 9574  Human Anatomy Atlas 2018: Complete 3D Human Body              MEDICAL
# 9575                        Red Hands – 2-Player Games                 GAME
# 9576                               Narcos: Cartel Wars               FAMILY
# 9577                                           Get 'Em                 GAME
# ...

# %% [markdown]
# **1 - "Review" Column** - "Review" column does not containg any type of symbol so we can easily change "Review" column data into numeric type data.

# %%
# Printing unique values of Reviews column

unq_value_of_review_clm_df = ps_df[('Reviews')].unique()
unq_value_of_review_clm_df
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
# Convering 'Reviews" column inot valid numeric column

ps_df[('Reviews')] = pd.to_numeric(ps_df['Reviews'])

# %% [markdown]
# **2 - "Price" Column** - "Price" column containg different type of symbols E.g. '$' and ',' so we are going to remove those symobls and change "Price" column data into numeric type data.

# %%
# Printing unique values of price column

unq_value_of_price_clm_df = ps_df[('Price')].unique()
unq_value_of_price_clm_df
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# Removing undefine symbols ['$' and ','] from 'Price column

symb_to_remove = ['$', ',']
colum_name = ['Price']

for symb in symb_to_remove:
  ps_df['Price'] = ps_df['Price'].astype(str).str.replace(symb, '', regex=True)

# %%
# Convering 'Price' column inot valid numeric column

ps_df['Price'] = pd.to_numeric(ps_df['Price'])

# %%
# After removing undefine symbols and converting column into valid numeric column
## New unique values of 'Price' column

new_unq_value_of_review_clm_df = ps_df['Price'].unique()
new_unq_value_of_review_clm_df
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %% [markdown]
# **3 - "Installs" Column** - "Installs" column containg different type of symbols E.g. '+' and ',' so we are going to remove those symobls and change "Installs" column data into numeric type data.

# %%
# Printing unique values of 'Installs' column

unq_value_of_installs_clm_df = ps_df[('Installs')].unique()
unq_value_of_installs_clm_df
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# Removing undefine symbols['+' and ',']

symb_to_remove = ['+', ',']
colum_name = ['Installs']

for symb in symb_to_remove:
  ps_df['Installs'] = ps_df['Installs'].astype(str).str.replace(symb, '', regex=True)

# %%
# Convering 'Installs' column inot valid numeric column

ps_df['Installs'] = pd.to_numeric(ps_df['Installs'])

# %%
# After removing undefine symbols and converting 'Instaals' column into valid numeric column
## New unique values of 'Installs' column

new_unq_value_of_installs_clm_df = ps_df['Installs'].unique()
new_unq_value_of_installs_clm_df
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %% [markdown]
# **4 - "Size" Column** - "Size" column containg different type of data size unit in string from E.g. 'M' for "MB" and 'K' for "KB" and also one another string value which is "Varies with device".
# * So now we are going to change different type of size unit in a single unit and removing "Varies with device" string from respective rows in 'Size' column.
# * Change "Size" column data into numeric (float) type data.

# %%
# Differrnt type value counts in 'Size' column

diff_value_size_clm_df = ps_df['Size'].value_counts()
diff_value_size_clm_df
# Out:
# Varies with device    1695
# 11M                    197
# 12M                    196
# 14M                    193
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: Size, Length: 457, dtype: int64

# %% [markdown]
# * As we know 1MB = 1024KB, to change the values 'KB' to 'MB' we going to devide KB values with 1024. So all values convert in single data size unit which is 'MB'.
# * And replacing "Varies with device" string values with '0' so we can get all column in numeric data type.

# %%
# We are going to define a function which change 'KB' values to 'MB' values and replace "Varies with device" string values with '0'
## Also change column data type into valid numeric (float) data form.

def kbvalue_to_mbvalue(val):
  '''This function change 'KB' values to 'MB' values and return us new values in float type data form '''
  try:
    if 'M' in val:
      return float(val[:-1])
    elif 'k' in val:
      return round(float(val[:-1])/1024, 2)
    elif 'Varies with device' in val: 
      return float(0)
    else:
      return val
  except:
    return val

# %%
# To change the values of 'Size' column we are going to apply "kbvalue_to_mbvalue" function in 'size' column

ps_df['Size'] = ps_df['Size'].apply (lambda x: kbvalue_to_mbvalue(x))
ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# After applying "kbvalue_to_mbvalue" function we get new type value counts in 'Size' column let's cross check it

new_value_size_clm_df = ps_df['Size'].value_counts()
new_value_size_clm_df
# Out:
# 0.00     1695
# 11.00     197
# 12.00     196
# 14.00     193
# 13.00     191
#          ...
# 0.78        1
# 0.48        1
# 0.10        1
# 0.91        1
# 0.66        1
# Name: Size, Length: 274, dtype: int64

# %%
# After change and clean the string values present into different columns and
## Converting 'Review','Price', 'Installs' and 'Size' columns into valid numeric columns let's cross check the data frame info

ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10830 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10830 non-null  object
#  1   Category        10830 non-null  object
#  2   Rating          10830 non-null  float64
#  3   Reviews         10830 non-null  int64
#  4   Size            10830 non-null  float64
#  5   Installs        10830 non-null  int64
#  6   Type            10830 non-null  object
#  7   Price           10830 non-null  float64
#  8   Content Rating  10830 non-null  object
#  9   Genres          10830 non-null  object
#  10  Last Updated    10830 non-null  object
#  11  Current Ver     10830 non-null  object
#  12  Android Ver     10830 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# # **Handling of duplicate values**
#
# * We are going to check duplicate values in different columns and eleminating those values from the dataset.
# * First we are going check to different columns value_counts() so we get the unique values count indivisualy present in the column.
# * If we find any repetiton present in respective column we will eliminate those repeat values from our main data frame.

# %%
# We are going check different value count in "App" column
## It's help us to find duplicate numbers of apps in "App" column

dupli_app_df = ps_df['App'].value_counts()
dupli_app_df
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# Candy Crush Saga                                      7
# 8 Ball Pool                                           7
# ESPN                                                  7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9649, dtype: int64

# %%
# Cross checking of duplicates values for App 'ROBLOX'.

ps_df[ps_df['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  Reviews  Size   Installs  Type  Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67.0  100000000  Free    0.0
# 1701  ROBLOX     GAME     4.5  4447346  67.0  100000000  Free    0.0
# 1748  ROBLOX     GAME     4.5  4448791  67.0  100000000  Free    0.0
# 1841  ROBLOX     GAME     4.5  4449882  67.0  100000000  Free    0.0
# 1870  ROBLOX     GAME     4.5  4449910  67.0  100000000  Free    0.0
# 2016  ROBLOX   FAMILY     4.5  4449910  67.0  100000000  Free    0.0
# 2088  ROBLOX   FAMILY     4.5  4450855  67.0  100000000  Free    0.0
# 2206  ROBLOX   FAMILY     4.5  4450890  67.0  100000000  Free    0.0
# 4527  ROBLOX   FAMILY     4.5  4443407  67.0  100000000  Free    0.0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %%
# Cross checking of duplicates values for App '8 Ball Pool'.

ps_df[ps_df['App'] == '8 Ball Pool']
# Out:
#               App Category  Rating   Reviews  Size   Installs  Type  Price  \
# 1675  8 Ball Pool     GAME     4.5  14198297  52.0  100000000  Free    0.0
# 1703  8 Ball Pool     GAME     4.5  14198602  52.0  100000000  Free    0.0
# 1755  8 Ball Pool     GAME     4.5  14200344  52.0  100000000  Free    0.0
# 1844  8 Ball Pool     GAME     4.5  14200550  52.0  100000000  Free    0.0
# 1871  8 Ball Pool     GAME     4.5  14201891  52.0  100000000  Free    0.0
# 1970  8 Ball Pool     GAME     4.5  14201604  52.0  100000000  Free    0.0
# 3953  8 Ball Pool   SPORTS     4.5  14184910  52.0  100000000  Free    0.0
#
#      Content Rating  Genres   Last Updated Current Ver   Android Ver
# 1675       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1703       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1755       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1844       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# ...

# %%
# Removing duplicates rows from the 'App' column 
## Use the drop method for removing  [ps_df.drop]

remove_dupli_app_df = ps_df.drop_duplicates(subset= 'App', inplace = True)
remove_dupli_app_df

# %%
# Checking of duplicates values in 'App' column after removing the value of data frame

wthout_dupli_app_df = ps_df['App'].value_counts()
wthout_dupli_app_df
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# INFAMY RO                                         1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
# CK Shop                                           1
#                                                  ..
# Block City Wars + skins export                    1
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: App, Length: 9649, dtype: int64

# %%
# After droping values updated shape of data frame

ps_df.shape
# Out:
# (9649, 13)

# %% [markdown]
# #**Dataset's output's and Data Visualition**

# %% [markdown]
# **1 - Find out top 10 installed Apps from Play store?**

# %%
# We are going to sort 'Installs' column values from the data frame
## Presenting those top 10 'Apps' in descending order [ascending=False]

top_10_apps = ps_df.sort_values(by=['Installs'], ascending=False,)
top_10_apps.head(10)
# Out:
#                             App             Category  Rating   Reviews  Size  \
# 3736                Google News   NEWS_AND_MAGAZINES     3.9    877635  13.0
# 3117  Maps - Navigate & Explore     TRAVEL_AND_LOCAL     4.3   9235155   0.0
# 3127         Google Street View     TRAVEL_AND_LOCAL     4.2   2129689   0.0
# 3665                    YouTube        VIDEO_PLAYERS     4.3  25655305   0.0
# 3687    Google Play Movies & TV        VIDEO_PLAYERS     3.7    906384   0.0
# 2554                    Google+               SOCIAL     4.2   4831125   0.0
# 2545                  Instagram               SOCIAL     4.5  66577313   0.0
# 2544                   Facebook               SOCIAL     4.1  78158306   0.0
# 3234                     Google                TOOLS     4.4   8033493   0.0
# 152           Google Play Books  BOOKS_AND_REFERENCE     3.9   1433233   0.0
#
#         Installs  Type  Price Content Rating                   Genres  \
# ...

# %% [markdown]
# **2 - Which are the most popular categories in play store find out top categories? plot bar graph for it.**

# %%
# Find out the most popular categories in play store
## we are going to grouby data in Categoy wise and sum the values which shows categories and its respective sum's

most_pop_cate_df = ps_df.groupby('Category').sum()
most_pop_cate_df
# Out:
#                      Rating    Reviews      Size     Installs    Price
# Category
# ART_AND_DESIGN        275.5    1419148    764.30    114333100     5.97
# AUTO_AND_VEHICLES     357.5    1163666   1502.76     53130211    13.47
# BEAUTY                227.0     396240    648.40     27197050     0.00
# BOOKS_AND_REFERENCE   957.9   16721306   2547.36   1665968576   119.77
# BUSINESS             1753.0    9890245   5213.97    697164865   175.29
# COMICS                234.4    2342071    675.92     44981150     0.00
# COMMUNICATION        1308.8  285811368   2736.14  11038276251    83.14
# DATING                691.1    3623544   2490.12    140926107    27.44
# EDUCATION             519.3   13364148   1696.05    352952000    17.96
# ENTERTAINMENT         421.8   34762650   1474.80   2113660000     7.98
# EVENTS                281.3     161018    795.93     15973161   109.99
# FAMILY               7671.5  143825265  46904.62   4427881405  2398.87
# ...

# %%
# plotting bar graph for the popular categories in playstore from the graph visualisation we found top category from it.
## For plotting this graph we take the help of matplotlib and seborn library

plt.figure(figsize=(20,10))

sns.set(font_scale =1.25)
sns.countplot(x=ps_df['Category'], data = most_pop_cate_df)
plt.ylabel('Number of Apps')
plt.xticks(rotation=90)
plt.title('Number of Apps by Category');
plt.show()

# %% [markdown]
# * From the upper graph visualisation we can see that FAMILY, GAMES and TOOLS are the top in category among the all categories from the playstore.

# %% [markdown]
# **3 - a) What is the total number of apps installs in each category? also plot a graph for it.**
#
# **b) Which are the Top 5 highest rating Apps in "GAME" category?**
#
# **c) Find out top 5 most Instlled app in MEDICAL category?**

# %% [markdown]
# a) Total number of apps installs in each category and a graph for it.

# %%
# Find out the total number of Apps installs in each category
## we are going to grouby data in 'Category' wise and 'Installs' wise and sum those values and sort the numbers we get.

ttl_app_install_df = ps_df.groupby(['Category'])['Installs'].sum().sort_values()
ttl_app_install_df
# Out:
# Category
# EVENTS                    15973161
# BEAUTY                    27197050
# PARENTING                 31521110
# MEDICAL                   38193177
# COMICS                    44981150
# LIBRARIES_AND_DEMO        51995910
# AUTO_AND_VEHICLES         53130211
# HOUSE_AND_HOME            97212461
# ART_AND_DESIGN           114333100
# DATING                   140926107
# FOOD_AND_DRINK           211798751
# EDUCATION                352952000
# WEATHER                  361100520
# FINANCE                  455348734
# MAPS_AND_NAVIGATION      503281890
# LIFESTYLE                503823539
# BUSINESS                 697164865
# SPORTS                  1096474498
# HEALTH_AND_FITNESS      1144022512
# SHOPPING                1400348785
# PERSONALIZATION         1532483782
# BOOKS_AND_REFERENCE     1665968576
# ENTERTAINMENT           2113660000
# NEWS_AND_MAGAZINES      2369217760
# TRAVEL_AND_LOCAL        2894887146
# VIDEO_PLAYERS           3926902720
# ...

# %%
# plotting bar graph for the popular categories in playstore from the graph visualisation we found top category from it.
## For plotting this graph we take the help of matplotlib and seborn library

ttl_app_install_df.plot.bar(figsize=(20,10), color = 'g')

plt.title('Total number of Apps Installs in each Category');
plt.ylabel('Total number of Apps Installs')
plt.xlabel('Apps Categories')

plt.show()

# %% [markdown]
# * As we can see in above graph that 'GAME' category is highest numbers of Installed Apps.
# * 'COMMUNICATION' and 'TOOLS' is 2nd highest and 3rd highest in the numbers of intsallation.

# %% [markdown]
# b) Top 5 highest rating Apps in "GAME" category.

# %%
# We are going to Compare "GAME" column values with the Category column
## sorting those values by Rating in descending order [ascending=False]

high_rate_df = ps_df[ps_df['Category'] == 'GAME'] 
high_rate_df = high_rate_df.sort_values(by=['Rating'], ascending=False)
high_rate_df.head(5)
# Out:
#                         App Category  Rating  Reviews  Size  Installs  Type  \
# 10776      Monster Ride Pro     GAME     5.0        1  24.0        10  Free
# 10697               Mu.F.O.     GAME     5.0        2  16.0         1  Paid
# 5795       Axe Champs! Wars     GAME     5.0        8  25.0        50  Free
# 7402   Trovami se ci riesci     GAME     5.0       11   6.1        10  Free
# 7698              CP Trivia     GAME     5.0        5  12.0       100  Free
#
#        Price Content Rating  Genres    Last Updated Current Ver Android Ver
# 10776   0.00       Everyone  Racing   March 5, 2018         2.0  2.3 and up
# 10697   0.99       Everyone  Arcade   March 3, 2017         1.0  2.3 and up
# 5795    0.00       Everyone  Arcade   June 26, 2018         1.1  4.1 and up
# 7402    0.00       Everyone  Arcade  March 11, 2017         0.1  2.3 and up
# 7698    0.00       Everyone  Trivia  August 6, 2018        0.99  5.0 and up

# %% [markdown]
# c) Top 5 most Instlled app in "MEDICAL" category.

# %%
# First we are going to fetch "MEDICAL" column values in Category column
## Sorting those values by Rating in descending order [ascending=False]

top5_med_app_df = ps_df[ps_df['Category'] == 'MEDICAL'] 
top5_med_app_df = top5_med_app_df.sort_values(by=['Installs'], ascending=False)
top5_med_app_df.head(18)
# Out:
#                                                     App Category  Rating  \
# 2310                                     Blood Pressure  MEDICAL     4.2
# 2319                       My Calendar - Period Tracker  MEDICAL     4.7
# 2303                     GoodRx Drug Prices and Coupons  MEDICAL     4.8
# 2316      Ovia Fertility Tracker & Ovulation Calculator  MEDICAL     4.8
# 2330                            Ada - Your Health Guide  MEDICAL     4.7
# 2304                                            MyChart  MEDICAL     4.2
# 2338                         Drugs.com Medication Guide  MEDICAL     4.4
# 2346                        Anatomy Learning - 3D Atlas  MEDICAL     4.5
# 2354                                     Epocrates Plus  MEDICAL     4.3
# 2322                         1800 Contacts - Lens Store  MEDICAL     4.7
# 2331  mySugr: the blood sugar tracker made just for you  MEDICAL     4.6
# 2333               Pregnancy Calculator and Tracker app  MEDICAL     4.8
# ...

# %% [markdown]
# **4 - How many age groups have rated in playstore find out the age group that rated in highest amount? Plot a pie chart for it.**

# %%
# We are going to find different Age groups which rated in playstore

dif_agegrp_df = ps_df['Content Rating'].value_counts()
dif_agegrp_df
# Out:
# Everyone           7893
# Teen               1036
# Mature 17+          393
# Everyone 10+        322
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
# plotting pie chart for the different age groups from that we find which age group rated in highest amount.
## For plotting this graph we take the help of matplotlib and seborn library

dif_agegrp_df.plot(kind='pie', fontsize=16, explode= (0.05,0.15,0.2,0.3,0.5,0.1), autopct='%1.2f%%', pctdistance=0.70, labeldistance=1.3)

# %% [markdown]
# * In the above Pie chart we find that, from the play store highest number of the apps used by 'Everyone' followed by 'Teen' and after then 'Mature 17+' age group.
# * Different type of apps have various age restrication to use it.

# %% [markdown]
# **5 - What kind of "Sentiment" do users use, which is the commonly used type of "Sentiment"? plot a bar graph for it.**

# %%
# We are going to find how many types "Sentiment" by used by users

diff_type_sentiment = ur_df['Sentiment'].value_counts()
diff_type_sentiment
# Out:
# Positive    23998
# Negative     8271
# Neutral      5163
# Name: Sentiment, dtype: int64

# %%
# plotting bar graph for the different type user sentiments from that we get most commonly used sentiment type.
## For plotting this graph we take the help of matplotlib library

plt.figure(figsize=(10,5))

sns.set(font_scale =1)
sns.countplot(x = ur_df['Sentiment'], data = diff_type_sentiment)
plt.ylabel("Count")
plt.title("Different type user sentiments");
plt.show()

# %% [markdown]
# * From the above bar graph we conclude that people with the positive sentiment give more feedback as compare to neutral and negative sentiment.

# %% [markdown]
# **6 - Find out "Apps" those contain highest number of postive reviews and highest number of  negative reviews? From all of the "Apps" Show top 20 "Apps" with sentiment numbers.**

# %%
# Going to find those "Apps" which are containing 'Positive' Sentiment

pst_review_df = ur_df[ur_df['Sentiment'] == 'Positive']
pst_review_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64217  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
# Top 20 "Apps" which are containing highest number of 'Positive' Sentiment

top20_pst_review_df = pst_review_df.groupby('App')['Sentiment'].value_counts().nlargest(20)
top20_pst_review_df
# Out:
# App                                                Sentiment
# Helix Jump                                         Positive     209
# Duolingo: Learn Languages Free                     Positive     200
# Calorie Counter - Macros                           Positive     174
# Bowmasters                                         Positive     169
# Calorie Counter - MyFitnessPal                     Positive     169
# 10 Best Foods for You                              Positive     162
# Google Photos                                      Positive     143
# 8fit Workouts & Meal Planner                       Positive     137
# Garena Free Fire                                   Positive     136
# DRAGON BALL LEGENDS                                Positive     127
# Angry Birds Classic                                Positive     124
# CBS Sports App - Scores, News, Stats & Watch Live  Positive     123
# ColorNote Notepad Notes                            Positive     121
# ...

# %%
# Going to find those "Apps" which are containing  'Negative' Sentiment

neg_review_df = ur_df[ur_df['Sentiment'] == 'Negative']
neg_review_df
# Out:
#                                   App  \
# 32              10 Best Foods for You
# 43              10 Best Foods for You
# 68              10 Best Foods for You
# 85              10 Best Foods for You
# 95              10 Best Foods for You
# ...                               ...
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# ...                                                  ...       ...
# ...

# %%
# Top 20 "Apps" which are containing highest number of 'Negative' Sentiment

top20_neg_review_df = neg_review_df.groupby('App')['Sentiment'].value_counts().nlargest(20)
top20_neg_review_df
# Out:
# App                                                Sentiment
# Angry Birds Classic                                Negative     147
# Candy Crush Saga                                   Negative     126
# Bowmasters                                         Negative     119
# 8 Ball Pool                                        Negative     106
# Candy Crush Soda Saga                              Negative      96
# Garena Free Fire                                   Negative      81
# Cooking Fever                                      Negative      79
# Alto's Adventure                                   Negative      72
# Block Puzzle                                       Negative      71
# Agar.io                                            Negative      66
# Gardenscapes                                       Negative      63
# Facebook                                           Negative      60
# Be A Legend: Soccer                                Negative      59
# ...

# %% [markdown]
# **7 - which are the "Apps" with the highest numbers of reviews? Find Top 5 "Apps" and display those apps and reviews number in graph.**

# %%
# We are going to sort "Reviews" column values so we can find the apps and there respective number of reviews

top_most_review_apps_df  = ps_df.sort_values(by='Reviews', ascending=False)
top_most_review_apps_df.head(10)
# Out:
#                                                     App       Category  \
# 2544                                           Facebook         SOCIAL
# 336                                  WhatsApp Messenger  COMMUNICATION
# 2545                                          Instagram         SOCIAL
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 1670                                     Clash of Clans           GAME
# 4005            Clean Master- Space Cleaner & Antivirus          TOOLS
# 1654                                     Subway Surfers           GAME
# 3665                                            YouTube  VIDEO_PLAYERS
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 1660                                       Clash Royale           GAME
#
#       Rating   Reviews  Size    Installs  Type  Price Content Rating  \
# 2544     4.1  78158306   0.0  1000000000  Free    0.0           Teen
# ...

# %%
# plotting bar graph for the Top 5 most reviewed 'App' in the play store
## For plotting this graph we take the help of matplotlib library

top5_reviewed_apps = top_most_review_apps_df.sort_values("Reviews",ascending=False,ignore_index=True).head()
plt.figure(figsize=(10,6))
sns.barplot(x ="Reviews",y="App",data=top5_reviewed_apps);

# %% [markdown]
# * From the above graph we can say that facebook is the highest reviewed application.
# * Social media and communication apps are the top most reviewed "Apps".

# %% [markdown]
# **8 - How many types of "App" are available in the playstore, which type of "App" is used most? plot a pie chart for it.**

# %%
# First we are going to find how many different types of "App" available in playstore

types_of_app_df = ps_df.Type.value_counts()
types_of_app_df
# Out:
# Free    8896
# Paid     753
# Name: Type, dtype: int64

# %%
# plotting pie chart for the "Apps" Type available in playstore from that we find which "App" type are mostly using bu users.
## For plotting this graph we take the help of matplotlib and seborn library.

types_of_app_df.plot(kind='pie', fontsize=20, explode= (0.05,0.1), autopct='%1.f%%', pctdistance=0.60, labeldistance=1.05)

# %% [markdown]
# * From the upper pie chart we can say that the most substantial portion consist by the 'Free' "Apps" in playstore.
# * Other hand 'Paid' "Apps" consist less place becuse theu charge certain amount to download and install the "Apps". Amount will differet for one "App" to another.

# %% [markdown]
# **9 - a) Find out top installs "Apps" that are 'Free' type?**
#
# **b) Find out top installs "Apps" that are 'Paid' type?**

# %% [markdown]
# a) Top installs "Apps" that are 'Free' type

# %%
# First we are going to fetch 'Free' values in "Type" column and creating different date frame for 'Free' values
## Sorting those values by 'Installs'

free_type_app_df = ps_df[ps_df['Type'] == 'Free']
free_type_app_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Top 'Free' Apps that are installed

top_free_type_app_df = free_type_app_df[free_type_app_df['Installs'] == free_type_app_df['Installs'].max()]
top_free_type_app_df
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 341                                   Hangouts        COMMUNICATION     4.0
# 391              Skype - free IM & video calls        COMMUNICATION     4.1
# 865                          Google Play Games        ENTERTAINMENT     4.3
# 1654                            Subway Surfers                 GAME     4.5
# 2544                                  Facebook               SOCIAL     4.1
# 2545                                 Instagram               SOCIAL     4.5
# ...

# %%
# Top free apps that are installed

top_free_type_app_df['App']
# Out:
# 152                            Google Play Books
# 335     Messenger – Text and Video Chat for Free
# 336                           WhatsApp Messenger
# 338                 Google Chrome: Fast & Secure
# 340                                        Gmail
# 341                                     Hangouts
# 391                Skype - free IM & video calls
# 865                            Google Play Games
# 1654                              Subway Surfers
# 2544                                    Facebook
# 2545                                   Instagram
# 2554                                     Google+
# 2808                               Google Photos
# 3117                   Maps - Navigate & Explore
# 3127                          Google Street View
# 3234                                      Google
# 3454                                Google Drive
# 3665                                     YouTube
# 3687                     Google Play Movies & TV
# ...

# %% [markdown]
# b) Top installs "Apps" that are 'paid' type

# %%
# First we are going to fetch 'Paid' values in "Type" column and creating different date frame for 'Paid' values
## Sorting those values by 'Installs'

paid_type_app_df = ps_df[ps_df['Type'] == 'Paid']
paid_type_app_df
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# ...

# %%
# Top 'paid'Apps that are installed

top_paid_type_app_df = paid_type_app_df[paid_type_app_df['Installs'] == paid_type_app_df['Installs'].max()]
top_paid_type_app_df
# Out:
#                 App Category  Rating  Reviews  Size  Installs  Type  Price  \
# 2241      Minecraft   FAMILY     4.5  2376564   0.0  10000000  Paid   6.99
# 4034  Hitman Sniper     GAME     4.6   408292  29.0  10000000  Paid   0.99
#
#      Content Rating                     Genres   Last Updated Current Ver  \
# 2241   Everyone 10+  Arcade;Action & Adventure  July 24, 2018     1.5.2.1
# 4034     Mature 17+                     Action  July 12, 2018  1.7.110758
#
#              Android Ver
# 2241  Varies with device
# 4034          4.1 and up

# %%
top_paid_type_app_df['App']
# Out:
# 2241        Minecraft
# 4034    Hitman Sniper
# Name: App, dtype: object

# %% [markdown]
# There are only two paid "Apps" { Minecraft and Hitman Sniper } with highest rating and 10M+ installs.

# %%
import plotly.express as px

# %%
x = ['Size']


fig = px.box(ps_df, y=x,points="all",color="Type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Summary**

# %% [markdown]
# After analyzing the play store data and user review data we find some intercting facts and got answers of undefine questions. which are very useful for any curious user.
#
# * Top Install Apps from the play store.
#
# * There are more then 20 apps that have been installed over a billion times.
#
# * Top most popular categories in play store.
#
# * FAMILY, GAMES and TOOLS are the top in category among the all categories from the playstore.
#
# * Category of highest number of App Installation is -'GAME'.
#
# * There are only 12 Apps that hold highest Rating == 5.0, in 'GAME' category.
#
# * 'Blood Pressure' and 'My Calendar - Period Tracke' are only 2 Apps from 'MEDICAL' category that have been Installed 5 Millions times.
#
# * Different age group peoples rate Apps in play store.
#
# * From all of them 'Everyone' age group rates in highest amount = ~82% .
#
# * Users use various kind of "Sentiment" during the feedback of an App.'Positive' sentiment used more as compare to 'Neutral' and 'Nagative' sentiment.
#
# * 'Helix Jump' App has highest number of 'positive' review where 'Angry Birds Classic' has highest number of 'Negative' review.
#
# * Social media and Communication types App are most reviewed applications snd basced on the number of reviews most popular App is -'Facebook'.
#
# * Percentage of 'Free' Apps =~ 92% whereas only 8% Apps are Paid.
#
# * There are only two paid Apps 'Minecraft and Hitman Sniper' with highest rating and 10M+ installs.
#
# * Most of the Apps in the play store have rated between the range 3.0 - 5.0 and also meadian = 4.3 for differnt ratings.
#
# * m

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# To complete this EDA project we use different types of python libraries.
# (Pandas, Numpy, Matplotlib.pyplot and Seaborn etc)
#
# Throughout complete this project we use and implement various concetpts we alredy teached.
#
# Inspection and exploration of the data frames and checking the data type available in provided data frame.
#
#
# Cleaning and handling of junk values (NAN values and error values). And do various type operations on that to change junk values to usable data form.
#
# Executing various python function and different libraries operation to change data values and convert into required data form.
#
# Data wrangling for get different and necessary outputs from cleaned and structured data frame.
#
# Using various data visulisation function and methods for the projection of summarised information from the data frame via whom anyone can easily understand and explain the outputs.
